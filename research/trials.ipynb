# %%
from box import ConfigBox

config_data = ConfigBox(data)

config_data.name
# Out:
# 'Harsh'

# %%
import yaml 
import os

yaml_file_path = "test.py"

# open the yaml file and loads its contents
with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

print(data)
# Out:
# {'name': 'Harsh', 'email': 'harsh811@gmail.com'}

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1z0mreUtRmR-P-magILsDR3T7M6IkGXtY/view?usp=drive_link"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1z0mreUtRmR-P-magILsDR3T7M6IkGXtY',
#  'view?usp=drive_link']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1z0mreUtRmR-P-magILsDR3T7M6IkGXtY'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix + file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY&confirm=t&uuid=98d0b9d8-5191-400e-8756-c9e8711e48ee
# To: d:\3_Machine learning\MLOPs\Object-Classification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:12<00:00, 3.86MB/s]
# 'Chest-CT-Scan-data.zip'
